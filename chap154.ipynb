# %% [markdown]
# ## Chap 1.5.4 Introduction to SIFT (Scale-Invariant Feature Transform)

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# ##### SIFT in OpenCV

# %%
# 에러
img = cv2.imread('sIMG_2164.jpg')
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) 

sift = cv2.SIFT()
kp = sift.detect(gray,None)

img=cv2.drawKeypoints(gray,kp)

cv2.imwrite('sift_keypoints.jpg',img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 5
#       2 gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#       4 sift = cv2.SIFT()
# ----> 5 kp = sift.detect(gray,None)
#       7 img=cv2.drawKeypoints(gray,kp)
#       9 cv2.imwrite('sift_keypoints.jpg',img)
#
# error: Unknown C++ exception from OpenCV code

# %%
img = cv2.imread('sIMG_2164.jpg')
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) 

sift = cv2.SIFT_create()
kp,des = sift.detectAndCompute(gray,None)

img=cv2.drawKeypoints(gray,kp, img)

cv2.imwrite('sift_keypoints.jpg',img)

plt.imshow(img)

# %%
img = cv2.imread('view1.png')
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) 

sift = cv2.SIFT_create()
kp,des = sift.detectAndCompute(gray,None)
img=cv2.drawKeypoints(gray,kp, img)

cv2.imwrite('sift_view1.jpg',img)

plt.imshow(img)

# %%
img = cv2.imread('view5.png')
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) 

sift = cv2.SIFT_create()
kp,des = sift.detectAndCompute(gray,None)
img=cv2.drawKeypoints(gray,kp, img)

cv2.imwrite('sift_view5.jpg',img)

plt.imshow(img)
